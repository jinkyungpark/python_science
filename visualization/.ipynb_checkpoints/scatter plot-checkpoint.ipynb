# %% [markdown]
# ### Scatter plot
# * 산점도 - 데이터 분포도, 데이터 사이의 연관관계 등을 볼 때 사용
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제 해결
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.910918  0.267264  0.691134  0.839818
# 1  0.317017  0.886106  0.693372  0.303304
# 2  0.242073  0.456815  0.324983  0.821717
# 3  0.552117  0.416503  0.899763  0.393853
# 4  0.328746  0.233867  0.642635  0.757401

# %%
# scatter 기본 형태 - x 축, y 축이 필수로 들어와야 함

df.plot.scatter(x='a', y='b')

# %%
# 점의 크기 설정 : s

df.plot.scatter(x='a', y='b', s=50)

# %%
# 색상지정

ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)

# %%
# c : 엑셀 z 축과 같은 개념

df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
# 숫자 * 200 을 해서 숫자가 클수록 점의 크기를 변경하는 형태

df.plot.scatter(x='a', y='b', s=df['c'] * 200)
